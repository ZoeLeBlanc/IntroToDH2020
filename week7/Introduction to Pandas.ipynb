# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.0.3'

# %%
film_scripts = pd.read_csv('pudding_public_scripts.csv')

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# read_csv(filepath_or_buffer: Union[str, pathlib.Path, IO[~AnyStr]], sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, cache_dates=True, iterator=False, chunksize=None, compression='infer', thousands=None, decimal: str = '.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, dialect=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
# ...

# %%
type(film_scripts)
# Out:
# pandas.core.frame.DataFrame

# %%
film_scripts
# Out:
#         imdb_id  script_id             title  year  \
# 0     tt0019777       4031     The Cocoanuts  1929
# 1     tt0021884       8521      Frankenstein  1931
# 2     tt0022054       1086   The Last Flight  1931
# 3     tt0022626       1631  American Madness  1932
# 4     tt0022958       2438       Grand Hotel  1932
# ...         ...        ...               ...   ...
# 1995  tt3733778       8533     Pay the Ghost  2015
# 1996  tt3808342       5499       Son of Saul  2015
# 1997  tt3850214       8056              Dope  2015
# 1998  tt3859076       5507             Truth  2015
# 1999  tt4270516       5410           Grandma  2015
#
#       gross (inflation-adjusted)  \
# 0                            NaN
# 1                          298.0
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 1995                         NaN
# 1996                         0.0
# 1997                        18.0
# ...

# %%
film_scripts.head()
# Out:
#      imdb_id  script_id             title  year  gross (inflation-adjusted)  \
# 0  tt0019777       4031     The Cocoanuts  1929                         NaN
# 1  tt0021884       8521      Frankenstein  1931                       298.0
# 2  tt0022054       1086   The Last Flight  1931                         NaN
# 3  tt0022626       1631  American Madness  1932                         NaN
# 4  tt0022958       2438       Grand Hotel  1932                         NaN
#
#                                                 link
# 0  http://www.pages.drexel.edu/~ina22/splaylib/Sc...
# 1  Frankenstein (Florey & Fort) [1931-5-23] [Scan...
# 2  film_20100519/all_imsdb_05_19_10/Last-Flight,-...
# 3  http://www.imsdb.com/Movie Scripts/American Ma...
# 4  http://www.imsdb.com/Movie Scripts/Grand Hotel...

# %%
film_scripts.sample(5)
# Out:
#         imdb_id  script_id                                      title  year  \
# 1161  tt0343818       8911                                   I, Robot  2004
# 1813  tt1764183       1684                                  Arbitrage  2012
# 833   tt0120915       3437  Star Wars: Episode I - The Phantom Menace  1999
# 1599  tt1176740       5170                                 Away We Go  2009
# 556   tt0107843       8058                         Point of No Return  1993
#
#       gross (inflation-adjusted)  \
# 1161                       203.0
# 1813                         8.0
# 833                        813.0
# 1599                        10.0
# 556                         63.0
#
#                                                    link
# 1161  http://indiegroundfilms.files.wordpress.com/20...
# 1813  http://www.imsdb.com/Movie Scripts/Arbitrage S...
# 833   http://www.scifiscripts.com/scripts/StarWars-E...
# 1599  http://www.screenplaydb.com/film/download/away...
# ...

# %%
film_scripts.shape
# Out:
# (2000, 6)

# %%
film_scripts.dtypes
# Out:
# imdb_id                        object
# script_id                       int64
# title                          object
# year                            int64
# gross (inflation-adjusted)    float64
# link                           object
# dtype: object

# %%
film_scripts['link'] # same as film_scripts.link
# Out:
# 0       http://www.pages.drexel.edu/~ina22/splaylib/Sc...
# 1       Frankenstein (Florey & Fort) [1931-5-23] [Scan...
# 2       film_20100519/all_imsdb_05_19_10/Last-Flight,-...
# 3       http://www.imsdb.com/Movie Scripts/American Ma...
# 4       http://www.imsdb.com/Movie Scripts/Grand Hotel...
#                               ...
# 1995                  Pay The Ghost (Dan Kay, 9-1-09).pdf
# 1996    http://gointothestory.blcklst.com/wp-content/u...
# 1997                      Dope (2013.10.31) [Digital].pdf
# 1998    http://gointothestory.blcklst.com/wp-content/u...
# 1999    http://gointothestory.blcklst.com/wp-content/u...
# Name: link, Length: 2000, dtype: object

# %%
film_scripts[['link']]
# Out:
#                                                    link
# 0     http://www.pages.drexel.edu/~ina22/splaylib/Sc...
# 1     Frankenstein (Florey & Fort) [1931-5-23] [Scan...
# 2     film_20100519/all_imsdb_05_19_10/Last-Flight,-...
# 3     http://www.imsdb.com/Movie Scripts/American Ma...
# 4     http://www.imsdb.com/Movie Scripts/Grand Hotel...
# ...                                                 ...
# 1995                Pay The Ghost (Dan Kay, 9-1-09).pdf
# 1996  http://gointothestory.blcklst.com/wp-content/u...
# 1997                    Dope (2013.10.31) [Digital].pdf
# 1998  http://gointothestory.blcklst.com/wp-content/u...
# 1999  http://gointothestory.blcklst.com/wp-content/u...
#
# [2000 rows x 1 columns]

# %%
film_scripts[0:5]
# Out:
#      imdb_id  script_id             title  year  gross (inflation-adjusted)  \
# 0  tt0019777       4031     The Cocoanuts  1929                         NaN
# 1  tt0021884       8521      Frankenstein  1931                       298.0
# 2  tt0022054       1086   The Last Flight  1931                         NaN
# 3  tt0022626       1631  American Madness  1932                         NaN
# 4  tt0022958       2438       Grand Hotel  1932                         NaN
#
#                                                 link
# 0  http://www.pages.drexel.edu/~ina22/splaylib/Sc...
# 1  Frankenstein (Florey & Fort) [1931-5-23] [Scan...
# 2  film_20100519/all_imsdb_05_19_10/Last-Flight,-...
# 3  http://www.imsdb.com/Movie Scripts/American Ma...
# 4  http://www.imsdb.com/Movie Scripts/Grand Hotel...

# %%
film_scripts[['link', 'title']]
# Out:
#                                                    link             title
# 0     http://www.pages.drexel.edu/~ina22/splaylib/Sc...     The Cocoanuts
# 1     Frankenstein (Florey & Fort) [1931-5-23] [Scan...      Frankenstein
# 2     film_20100519/all_imsdb_05_19_10/Last-Flight,-...   The Last Flight
# 3     http://www.imsdb.com/Movie Scripts/American Ma...  American Madness
# 4     http://www.imsdb.com/Movie Scripts/Grand Hotel...       Grand Hotel
# ...                                                 ...               ...
# 1995                Pay The Ghost (Dan Kay, 9-1-09).pdf     Pay the Ghost
# 1996  http://gointothestory.blcklst.com/wp-content/u...       Son of Saul
# 1997                    Dope (2013.10.31) [Digital].pdf              Dope
# 1998  http://gointothestory.blcklst.com/wp-content/u...             Truth
# 1999  http://gointothestory.blcklst.com/wp-content/u...           Grandma
#
# [2000 rows x 2 columns]

# %%
print(type(film_scripts['link']))
print(type(film_scripts[['link']]))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
film_scripts['link'].tolist()
# Out:
# ['http://www.pages.drexel.edu/~ina22/splaylib/Screenplay-Cocoanuts,_The.pdf',
#  'Frankenstein (Florey & Fort) [1931-5-23] [Scan].pdf',
#  'film_20100519/all_imsdb_05_19_10/Last-Flight,-The.html',
#  'http://www.imsdb.com/Movie Scripts/American Madness Script.html',
#  'http://www.imsdb.com/Movie Scripts/Grand Hotel Script.html',
#  'http://www.aellea.com/emruf3/tip.html',
#  'http://www.aellea.com/scripts/WHAT.pdf',
#  'film_20100519/all_imsdb_05_19_10/Duck-Soup.html',
#  'King Kong - 1933 Orig. (Includes End Notes) (Digital).pdf',
#  'http://www.aellea.com/script/qWAX.htm',
#  'http://www.dailyscript.com/scripts/thethinman.html',
#  'http://www.aellea.com/emruf3/tm.html',
#  'http://www.imsdb.com/Movie Scripts/Mr Deeds Goes to Town Script.html',
#  'http://www.imsdb.com/Movie Scripts/Lost Horizon Script.html',
#  'http://www.dailyscript.com/scripts/Mr%20Smith%20Goes%20To%20Washington.txt',
#  'http://www.dailyscript.com/scripts/Ninotchka.txt',
# ...

# %%
film_scripts.rename(columns={'link': 'source'})
# Out:
#         imdb_id  script_id             title  year  \
# 0     tt0019777       4031     The Cocoanuts  1929
# 1     tt0021884       8521      Frankenstein  1931
# 2     tt0022054       1086   The Last Flight  1931
# 3     tt0022626       1631  American Madness  1932
# 4     tt0022958       2438       Grand Hotel  1932
# ...         ...        ...               ...   ...
# 1995  tt3733778       8533     Pay the Ghost  2015
# 1996  tt3808342       5499       Son of Saul  2015
# 1997  tt3850214       8056              Dope  2015
# 1998  tt3859076       5507             Truth  2015
# 1999  tt4270516       5410           Grandma  2015
#
#       gross (inflation-adjusted)  \
# 0                            NaN
# 1                          298.0
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 1995                         NaN
# 1996                         0.0
# 1997                        18.0
# ...

# %%
film_scripts.rename(columns={'link': 'source'}, inplace=True)

# %%
film_scripts
# Out:
#         imdb_id  script_id             title  year  \
# 0     tt0019777       4031     The Cocoanuts  1929
# 1     tt0021884       8521      Frankenstein  1931
# 2     tt0022054       1086   The Last Flight  1931
# 3     tt0022626       1631  American Madness  1932
# 4     tt0022958       2438       Grand Hotel  1932
# ...         ...        ...               ...   ...
# 1995  tt3733778       8533     Pay the Ghost  2015
# 1996  tt3808342       5499       Son of Saul  2015
# 1997  tt3850214       8056              Dope  2015
# 1998  tt3859076       5507             Truth  2015
# 1999  tt4270516       5410           Grandma  2015
#
#       gross (inflation-adjusted)  \
# 0                            NaN
# 1                          298.0
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 1995                         NaN
# 1996                         0.0
# 1997                        18.0
# ...

# %%
film_scripts['link'] = film_scripts['source']

# %%
film_scripts_dropped = film_scripts.drop(['link'], axis=1) #inplace=True is another option
# Out:
#         imdb_id  script_id             title  year  gross_cost  \
# 0     tt0019777       4031     The Cocoanuts  1929         NaN
# 1     tt0021884       8521      Frankenstein  1931       298.0
# 2     tt0022054       1086   The Last Flight  1931         NaN
# 3     tt0022626       1631  American Madness  1932         NaN
# 4     tt0022958       2438       Grand Hotel  1932         NaN
# ...         ...        ...               ...   ...         ...
# 1995  tt3733778       8533     Pay the Ghost  2015         NaN
# 1996  tt3808342       5499       Son of Saul  2015         0.0
# 1997  tt3850214       8056              Dope  2015        18.0
# 1998  tt3859076       5507             Truth  2015         2.0
# 1999  tt4270516       5410           Grandma  2015         7.0
#
#                                                  source
# 0     http://www.pages.drexel.edu/~ina22/splaylib/Sc...
# 1     Frankenstein (Florey & Fort) [1931-5-23] [Scan...
# ...

# %%
film_scripts.sort_values(by=['title'])
# Out:
#         imdb_id  script_id                       title  year  gross_cost  \
# 1538  tt1022603       1534        (500) Days of Summer  2009        37.0
# 897   tt0147800       1512  10 Things I Hate About You  1999        65.0
# 1864  tt2024544       1517            12 Years a Slave  2013        60.0
# 1282  tt0417385       1514              12 and Holding  2005         NaN
# 1753  tt1542344       1520                   127 Hours  2010        20.0
# ...         ...        ...                         ...   ...         ...
# 831   tt0120906       8158                 Zero Effect  1998         3.0
# 1292  tt0421090       3768                  Zerophilia  2005         NaN
# 1326  tt0443706       6491                      Zodiac  2007        41.0
# 832   tt0120907       6973                    eXistenZ  1999         4.0
# 1097  tt0295701       1497                         xXx  2002       211.0
#
#                                                  source  \
# ...

# %%
film_scripts.columns
# Out:
# Index(['imdb_id', 'script_id', 'title', 'year', 'gross (inflation-adjusted)',
#        'link'],
#       dtype='object')

# %%
film_scripts.rename(columns={'gross (inflation-adjusted)': 'gross_ia'}, inplace=True)

# %%
film_scripts[['gross_ia']]
# Out:
#       gross_ia
# 0          NaN
# 1        298.0
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 1995       NaN
# 1996       0.0
# 1997      18.0
# 1998       2.0
# 1999       7.0
#
# [2000 rows x 1 columns]

# %%
film_scripts['gross_ia'] >= 0
# Out:
# 0       False
# 1        True
# 2       False
# 3       False
# 4       False
#         ...
# 1995    False
# 1996     True
# 1997     True
# 1998     True
# 1999     True
# Name: gross_ia, Length: 2000, dtype: bool

# %%
film_scripts['gross_ia'].isna()
# Out:
# 0        True
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 1995     True
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Name: gross_ia, Length: 2000, dtype: bool

# %%
film_scripts[film_scripts.gross_ia >= 0] # film_scripts[film_scripts.gross_ia.isna() == False]
# Out:
#         imdb_id  script_id                title  year  gross_ia  \
# 1     tt0021884       8521         Frankenstein  1931     298.0
# 15    tt0031725       3016            Ninotchka  1939      45.0
# 16    tt0032138       1483     The Wizard of Oz  1939     839.0
# 23    tt0035423       1213       Kate & Leopold  2001      72.0
# 40    tt0041959       6003        The Third Man  1949       8.0
# ...         ...        ...                  ...   ...       ...
# 1994  tt3722070       5491  The Lady in the Van  2015       0.0
# 1996  tt3808342       5499          Son of Saul  2015       0.0
# 1997  tt3850214       8056                 Dope  2015      18.0
# 1998  tt3859076       5507                Truth  2015       2.0
# 1999  tt4270516       5410              Grandma  2015       7.0
#
#                                                    link
# 1     Frankenstein (Florey & Fort) [1931-5-23] [Scan...
# 15     http://www.dailyscript.com/scripts/Ninotchka.txt
# ...

# %%
film_scripts_cleaned = film_scripts[film_scripts.gross_ia.isna() == False]

# %%
film_scripts_cleaned.gross_ia.sum()
# Out:
# 172749.0

# %%
film_scripts_cleaned.year.value_counts()
# Out:
# 2009    87
# 2010    82
# 2011    79
# 2014    69
# 1999    66
# 2008    64
# 2013    64
# 2007    60
# 2012    60
# 1997    59
# 1998    58
# 2001    58
# 2000    55
# 2005    53
# 2002    51
# 1995    50
# 1996    49
# 2015    47
# 2004    47
# 2003    46
# 2006    45
# 1992    43
# 1993    42
# 1994    36
# 1991    36
# 1989    35
# 1990    32
# 1987    25
# 1988    22
# 1986    19
# 1984    18
# 1985    16
# 1983    13
# 1982    13
# 1981     9
# 1980     9
# 1979     5
# 1972     4
# 1973     4
# 1974     3
# 1977     3
# 1978     3
# 1975     3
# 1976     2
# 1958     2
# 1939     2
# 1968     2
# 1966     2
# 1954     2
# 1959     2
# 1949     1
# 1967     1
# 1960     1
# 1970     1
# 1971     1
# 1931     1
# Name: year, dtype: int64

# %%
film_scripts_cleaned.groupby('year')

# %%
film_scripts_cleaned.groupby('year').describe()
# Out:
#      script_id                                                              \
#          count         mean          std     min      25%     50%      75%
# year
# 1931       1.0  8521.000000          NaN  8521.0  8521.00  8521.0  8521.00
# 1939       2.0  2249.500000  1083.994696  1483.0  1866.25  2249.5  2632.75
# 1949       1.0  6003.000000          NaN  6003.0  6003.00  6003.0  6003.00
# 1954       2.0  3963.500000  1105.207899  3182.0  3572.75  3963.5  4354.25
# 1958       2.0  4832.500000  1659.579615  3659.0  4245.75  4832.5  5419.25
# 1959       2.0  5257.500000   378.302128  4990.0  5123.75  5257.5  5391.25
# 1960       1.0  1251.000000          NaN  1251.0  1251.00  1251.0  1251.00
# 1966       2.0  4427.500000  3744.130406  1780.0  3103.75  4427.5  5751.25
# 1967       1.0  5534.000000          NaN  5534.0  5534.00  5534.0  5534.00
# 1968       2.0  2708.000000  2945.806850   625.0  1666.50  2708.0  3749.50
# ...

# %%
films_year = film_scripts_cleaned.groupby('year')
films_year.get_group(2009)
# Out:
#         imdb_id  script_id                                   title  year  \
# 1138  tt0327597       5392                                Coraline  2009
# 1176  tt0361748       4423                    Inglourious Basterds  2009
# 1178  tt0362478       1909                                 The Box  2009
# 1186  tt0365929       1471                                Whiteout  2009
# 1228  tt0386117       5221               Where the Wild Things Are  2009
# ...         ...        ...                                     ...   ...
# 1647  tt1259571       5164             The Twilight Saga: New Moon  2009
# 1648  tt1263670       4050                             Crazy Heart  2009
# 1650  tt1266029       4725                             Nowhere Boy  2009
# 1661  tt1300851       3952  The Boondock Saints II: All Saints Day  2009
# 1666  tt1315981       4963                            A Single Man  2009
#
#       gross_ia                                               link
# ...

# %%
films_year = film_scripts_cleaned.groupby('year')['gross_ia'].sum().reset_index()

# %%
films_year
# Out:
#     year  gross_ia
# 0   1931     298.0
# 1   1939     884.0
# 2   1949       8.0
# 3   1954     215.0
# 4   1958      67.0
# 5   1959    1306.0
# 6   1960     545.0
# 7   1966      53.0
# 8   1967    1029.0
# 9   1968     548.0
# 10  1970     458.0
# 11  1971     101.0
# 12  1972    1524.0
# 13  1973    1720.0
# 14  1974    1225.0
# 15  1975    1718.0
# 16  1976     579.0
# 17  1977    2445.0
# 18  1978     686.0
# 19  1979     800.0
# 20  1980    2797.0
# 21  1981    1117.0
# 22  1982    1662.0
# 23  1983    2333.0
# 24  1984    2627.0
# 25  1985    1753.0
# 26  1986    2180.0
# 27  1987    2110.0
# 28  1988    2370.0
# 29  1989    3971.0
# 30  1990    4235.0
# 31  1991    4453.0
# 32  1992    4133.0
# 33  1993    4220.0
# 34  1994    4809.0
# 35  1995    3975.0
# 36  1996    5233.0
# 37  1997    7525.0
# 38  1998    5948.0
# 39  1999    7786.0
# 40  2000    4952.0
# 41  2001    6293.0
# 42  2002    5296.0
# 43  2003    5676.0
# 44  2004    5381.0
# 45  2005    5334.0
# ...
